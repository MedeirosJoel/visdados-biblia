# %%
from main import versions
from matplotlib import pyplot as plt
from wordcloud import WordCloud
data = {}
wordclouds = {}

# %% [markdown]
# ## Carregador dos arquivos

# %%
for version in versions:
    file = open(f"txt/{version}.txt", 'r', encoding='UTF8')
    data[version] = file.read()
    file.close()

# %% [markdown]
# ## Função que gera o wordcloud

# %%
def gerarWordcloudPlot(version):
    wordclouds[version] = WordCloud(background_color='black', width=1000, height=1000, ).generate(data[version])

    fig, ax = plt.subplots(figsize=(10, 10))
    ax.imshow(wordclouds[version], interpolation='bilinear')
    ax.set_axis_off()
    textversion = version.upper()
    ax.set_title(textversion, )
    plt.imshow(wordclouds[version])

# %% [markdown]
# ## Iterador para gerar todas as wordclouds das versões

# %%
for version in versions:
    gerarWordcloudPlot(version)
    pass
